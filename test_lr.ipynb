# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import cholesky

from datasets import load_dataset
from energies import LowRankEnergy
from sampling import AdaptiveSampler

# %%
def get_components_naive(G, indices):
    L = cholesky(G[np.ix_(indices, indices)], lower=True)
    W = np.linalg.inv(G[np.ix_(indices, indices)]) @ G[indices,:]
    f = np.diag(np.linalg.inv(G[np.ix_(indices, indices)])).real
    d = np.diag(G).real - np.sum(W.conj() * G[indices,:], axis=0).real
    return L, W, f, d


def check_components(energy, t=None, verbose=True, nround=4):
    if t is not None:
        indices = energy.indices[:t] + energy.indices[t+1:]
        indices_t = list(range(t)) + list(range(t+1, len(energy.indices)))
    else:
        indices = energy.indices[:]
        indices_t = list(range(len(energy.indices)))

    L_naive, W_naive, f_naive, d_naive = get_components_naive(energy.G, indices)
    matchL = np.allclose(energy.L[np.ix_(indices_t, indices_t)], L_naive)
    matchW = np.allclose(energy.W[indices_t, :], W_naive)
    matchf = np.allclose(energy.f[indices_t], f_naive)
    matchd = np.allclose(energy.d, d_naive)
    print("all match: ", matchL and matchW and matchf and matchd)
    
    print("L close:", matchL)
    if not matchL and verbose:
        print("Computed L:\n", np.round(energy.L[np.ix_(indices_t, indices_t)], nround))
        print("Naive L:\n", np.round(L_naive, nround))
    print("W close:", matchW)
    if not matchW and verbose:
        print("Computed W:\n", np.round(energy.W[indices_t, :], nround))
        print("Naive W:\n", np.round(W_naive, nround))
        print("full self.W:\n", np.round(energy.W, nround))
    print("f close:", matchf)
    if not matchf and verbose:
        print("Computed f:\n", np.round(energy.f[indices_t],nround))
        print("Naive f:\n", np.round(f_naive, nround))
        print("full self.f:\n", np.round(energy.f, nround))
    print("d close:", matchd)
    if not matchd and verbose:
        print("Computed d:\n", np.round(energy.d, nround))
        print("Naive d:\n", np.round(d_naive, nround))
    
    if matchL and matchW and matchf and matchd and (t is not None) and verbose:
        print("All components match naive computation!")
        print("L @ t:\n", np.round(energy.L[t, :], nround)) 
        print("W @ t:\n", np.round(energy.W[t, :], nround))
        print("f @ t:\n", np.round(energy.f[t], nround))
        print("d @ t:\n", np.round(energy.d[t], nround))
    return

# %% [markdown]
# ## Interpolative Update/Downdate Unit Tests
#
# Algorithms 9.4, 9.5

# %%
rand_state = np.random.RandomState(42)

m, n = 40,70
k = 20
X = rand_state.randn(m, n) + 1j*rand_state.randn(m, n)
energy = LowRankEnergy(X, p=2)
sampler = AdaptiveSampler(energy, seed=42)

sampler.build_phase(k, method="search") # build with k points

check_components(energy)
# Out:
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True

# %%
print("initial indices: ", energy.indices)
for t in range(len(energy.indices)):
    print("----- Testing index t =", t, " -----")
    # downdate 1 point
    print("Check downdate at t =", t)
    energy.downdate(t) 
    check_components(energy, t=t, verbose=False)
    print("indices after downdate:  ", energy.indices)
    print() 

    # update with a new point
    i = n // 2
    while i in energy.indices:
        i += 1
    print("Check update at t =", t, " with i =", i)
    energy.update(t, i)
    check_components(energy, t=None, verbose=False)
    print("indices after update:  ", energy.indices)
    print()
# Out:
# initial indices:  [np.int64(56), np.int64(18), np.int64(21), np.int64(67), np.int64(40), np.int64(28), np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
# ----- Testing index t = 0  -----
# Check downdate at t = 0
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [np.int64(56), np.int64(18), np.int64(21), np.int64(67), np.int64(40), np.int64(28), np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 0  with i = 36
# t, f[t]: 0 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, np.int64(18), np.int64(21), np.int64(67), np.int64(40), np.int64(28), np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 1  -----
# Check downdate at t = 1
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, np.int64(18), np.int64(21), np.int64(67), np.int64(40), np.int64(28), np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 1  with i = 38
# t, f[t]: 1 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, np.int64(21), np.int64(67), np.int64(40), np.int64(28), np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 2  -----
# Check downdate at t = 2
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, np.int64(21), np.int64(67), np.int64(40), np.int64(28), np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 2  with i = 39
# t, f[t]: 2 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, np.int64(67), np.int64(40), np.int64(28), np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 3  -----
# Check downdate at t = 3
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, np.int64(67), np.int64(40), np.int64(28), np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 3  with i = 41
# t, f[t]: 3 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, np.int64(40), np.int64(28), np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 4  -----
# Check downdate at t = 4
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, np.int64(40), np.int64(28), np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 4  with i = 42
# t, f[t]: 4 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, np.int64(28), np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 5  -----
# Check downdate at t = 5
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, np.int64(28), np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 5  with i = 40
# t, f[t]: 5 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 6  -----
# Check downdate at t = 6
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, np.int64(43), np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 6  with i = 44
# t, f[t]: 6 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 7  -----
# Check downdate at t = 7
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, np.int64(63), np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 7  with i = 43
# t, f[t]: 7 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 8  -----
# Check downdate at t = 8
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, 43, np.int64(16), np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 8  with i = 45
# t, f[t]: 8 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, 45, np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 9  -----
# Check downdate at t = 9
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, 43, 45, np.int64(4), np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 9  with i = 46
# t, f[t]: 9 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 10  -----
# Check downdate at t = 10
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, np.int64(0), np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 10  with i = 47
# t, f[t]: 10 1.5300261058115439e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 11  -----
# Check downdate at t = 11
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, np.int64(3), np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 11  with i = 48
# t, f[t]: 11 6.637052019087264e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 12  -----
# Check downdate at t = 12
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, np.int64(35), np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 12  with i = 49
# t, f[t]: 12 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 13  -----
# Check downdate at t = 13
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, np.int64(37), np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 13  with i = 35
# t, f[t]: 13 4.865205460724553e-14
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 14  -----
# Check downdate at t = 14
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, np.int64(9), np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 14  with i = 37
# t, f[t]: 14 1.5082032844837556e-13
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, 37, np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 15  -----
# Check downdate at t = 15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, 37, np.int64(64), np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 15  with i = 50
# t, f[t]: 15 2.2439654301376066e-12
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, 37, 50, np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 16  -----
# Check downdate at t = 16
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, 37, 50, np.int64(24), np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 16  with i = 51
# t, f[t]: 16 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, 37, 50, 51, np.int64(60), np.int64(69), np.int64(8)]
#
# ----- Testing index t = 17  -----
# Check downdate at t = 17
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, 37, 50, 51, np.int64(60), np.int64(69), np.int64(8)]
#
# Check update at t = 17  with i = 52
# t, f[t]: 17 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, 37, 50, 51, 52, np.int64(69), np.int64(8)]
#
# ----- Testing index t = 18  -----
# Check downdate at t = 18
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, 37, 50, 51, 52, np.int64(69), np.int64(8)]
#
# Check update at t = 18  with i = 53
# t, f[t]: 18 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, 37, 50, 51, 52, 53, np.int64(8)]
#
# ----- Testing index t = 19  -----
# Check downdate at t = 19
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after downdate:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, 37, 50, 51, 52, 53, np.int64(8)]
#
# Check update at t = 19  with i = 54
# t, f[t]: 19 1e-15
# all match:  True
# L close: True
# W close: True
# f close: True
# d close: True
# indices after update:   [36, 38, 39, 41, 42, 40, 44, 43, 45, 46, 47, 48, 49, 35, 37, 50, 51, 52, 53, 54]

# %% [markdown]
# ## Swap Tests

# %%
rand_state = np.random.RandomState(42)

m, n = 10,90
k = 5
X = rand_state.randn(m, n) + 1j*rand_state.randn(m, n)
energy = LowRankEnergy(X, p=2)

sampler = AdaptiveSampler(energy, seed=42)
sampler.build_phase(k, method="search") # build with k points

# %%
sampler.swap_phase("search", debug=False)

# %%
sampler.swap_phase("sampling", debug=True)
# Out:
# Best energy found during sampling swap: 26.996541784469144
# Energy at end of sampling swap: 29.100993954668592
# Re-initializing Energy object to best found indices...
